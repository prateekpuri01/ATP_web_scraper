# %%
import scraper_lib

# %%
if __name__ == '__main__':
    for year in range(1991,2020):
        scraper_lib.get_all_tourn_data(year)
# Out:
# Year: 1991
# Fetching match links...
# 136 links fetched
# Error has occured on https://www.atptour.com//en/scores/1991/408/MS027/match-stats?isLive=False, skipping match...
# Error has occured on https://www.atptour.com//en/scores/1991/408/MS025/match-stats?isLive=False, skipping match...
# Error has occured on https://www.atptour.com//en/scores/1991/424/MS030/match-stats?isLive=False, skipping match...
# Error has occured on https://www.atptour.com//en/scores/1991/201/MS026/match-stats?isLive=False, skipping match...
# Error has occured on https://www.atptour.com//en/scores/1991/329/MS043/match-stats?isLive=False, skipping match...
# Error has occured on https://www.atptour.com//en/scores/1991/346/MS016/match-stats?isLive=False, skipping match...
# Error has occured on https://www.atptour.com//en/scores/1991/717/MS001/match-stats?isLive=False, skipping match...
# Error has occured on https://www.atptour.com//en/scores/1991/717/MS003/match-stats?isLive=False, skipping match...
# ...
